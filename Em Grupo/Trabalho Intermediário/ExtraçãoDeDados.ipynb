# %%
import pandas as pd
import numpy as np

# %run Biblioteca.ipynb

# %%
df = pd.read_csv('dados.csv')

# %%
df['Ano_Ingresso'] = pd.to_numeric(df['Ano_Ingresso'])
df['CR'] = pd.to_numeric(df['CR'])
df['Joga_Algo'] = df['Joga_Algo']==1
df['Joga_LoL'] = df['Joga_LoL']==1

# %%
players = []
semNicks = df['Nick'].isnull()
n = 0
for linha in df.itertuples():
    if semNicks[n] != True:
        players.append(Player(linha.Nick))
    else:
        players.append(None)
    n = n+1

# %%
for jogador in players:
    if jogador != None:
        print("Nick: **********")
        print("ID: " + jogador.Summoner.accountId)
        print("Nível: " + jogador.Summoner.summonerLevel)
        print("Total de Partidas: " +  jogador.MatchList.totalGames)
        print("Total de Tempo de Jogo (estimado): " +  jogador.MatchList.totalHours + " horas")
        print("Campeão preferido: " + jogador.Champions.mainChampionName)
        print("Maestria com o Campeão: " + jogador.Champions.mainChampionPoints)
        print("Elo: "+ jogador.Leagues.tier)
        print("Divisão: " + jogador.Leagues.rank)
        print("Vitórias: " + str(jogador.Leagues.wins))
        print("Derrotas: " + str(jogador.Leagues.losses))
        print("Porcentagem de Vitórias: " + str(jogador.Leagues.winrate) + "%")
        print("==================================================================")
# Out:
# Nick: **********
# ID: 200304136
# Nível: 91
# Total de Partidas: 3777
# Total de Tempo de Jogo (estimado): 2203 horas
# Campeão preferido: Yasuo
# Maestria com o Campeão: 125119
# Elo: GOLD
# Divisão: I
# Vitórias: 11
# Derrotas: 22
# Porcentagem de Vitórias: 33.33%
# ==================================================================
# Nick: **********
# ID: 213331961
# Nível: 166
# Total de Partidas: 4809
# Total de Tempo de Jogo (estimado): 2805 horas
# Campeão preferido: Braum
# Maestria com o Campeão: 141776
# Elo: PLATINUM
# Divisão: III
# Vitórias: 142
# Derrotas: 122
# Porcentagem de Vitórias: 53.79%
# ==================================================================
# Nick: **********
# ID: 205747689
# Nível: 86
# Total de Partidas: 1738
# Total de Tempo de Jogo (estimado): 1013 horas
# Campeão preferido: Miss Fortune
# Maestria com o Campeão: 24135
# Elo:
# Divisão:
# Vitórias:
# Derrotas:
# Porcentagem de Vitórias: %
# ==================================================================
# Nick: **********
# ID: 201458849
# Nível: 115
# Total de Partidas: 3707
# Total de Tempo de Jogo (estimado): 2162 horas
# Campeão preferido: Janna
# Maestria com o Campeão: 142635
# Elo: GOLD
# Divisão: IV
# Vitórias: 36
# Derrotas: 32
# Porcentagem de Vitórias: 52.94%
# ==================================================================
# Nick: **********
# ID: 210725644
# Nível: 115
# Total de Partidas: 3185
# Total de Tempo de Jogo (estimado): 1857 horas
# Campeão preferido: Tahm Kench
# Maestria com o Campeão: 206102
# Elo: SILVER
# Divisão: II
# Vitórias: 76
# Derrotas: 86
# Porcentagem de Vitórias: 46.91%
# ==================================================================
# Nick: **********
# ID: 215095300
# Nível: 140
# Total de Partidas: 3379
# Total de Tempo de Jogo (estimado): 1971 horas
# Campeão preferido: Zed
# Maestria com o Campeão: 219967
# Elo: PLATINUM
# Divisão: V
# Vitórias: 166
# Derrotas: 155
# Porcentagem de Vitórias: 51.71%
# ==================================================================
# Nick: **********
# ID: 202135935
# Nível: 104
# Total de Partidas: 2819
# Total de Tempo de Jogo (estimado): 1644 horas
# Campeão preferido: Rek'Sai
# Maestria com o Campeão: 134568
# Elo: PLATINUM
# Divisão: IV
# Vitórias: 10
# Derrotas: 0
# Porcentagem de Vitórias: 100.0%
# ==================================================================
# Nick: **********
# ID: 200585791
# Nível: 122
# Total de Partidas: 4100
# Total de Tempo de Jogo (estimado): 2391 horas
# Campeão preferido: Poppy
# Maestria com o Campeão: 200136
# Elo: DIAMOND
# Divisão: V
# Vitórias: 27
# Derrotas: 11
# Porcentagem de Vitórias: 71.05%
# ==================================================================
# Nick: **********
# ID: 214947813
# Nível: 80
# Total de Partidas: 1584
# Total de Tempo de Jogo (estimado): 924 horas
# Campeão preferido: Miss Fortune
# Maestria com o Campeão: 122222
# Elo: GOLD
# Divisão: IV
# Vitórias: 87
# Derrotas: 74
# Porcentagem de Vitórias: 54.04%
# ==================================================================
# Nick: **********
# ID: 204808303
# Nível: 107
# Total de Partidas: 1603
# Total de Tempo de Jogo (estimado): 935 horas
# Campeão preferido: Jax
# Maestria com o Campeão: 63944
# Elo: SILVER
# Divisão: III
# Vitórias: 11
# Derrotas: 13
# Porcentagem de Vitórias: 45.83%
# ==================================================================
# Nick: **********
# ID: 217440093
# Nível: 113
# Total de Partidas: 1340
# Total de Tempo de Jogo (estimado): 781 horas
# Campeão preferido: Zoe
# Maestria com o Campeão: 110873
# Elo: SILVER
# Divisão: IV
# Vitórias: 17
# Derrotas: 26
# Porcentagem de Vitórias: 39.53%
# ==================================================================
# Nick: **********
# ID: 204265094
# Nível: 80
# Total de Partidas: 1157
# Total de Tempo de Jogo (estimado): 674 horas
# Campeão preferido: Alistar
# Maestria com o Campeão: 91092
# Elo: GOLD
# Divisão: V
# Vitórias: 100
# Derrotas: 87
# Porcentagem de Vitórias: 53.48%
# ==================================================================
# Nick: **********
# ID: 1712879
# Nível: 75
# Total de Partidas: 2264
# Total de Tempo de Jogo (estimado): 1320 horas
# Campeão preferido: Lee Sin
# Maestria com o Campeão: 175084
# Elo: GOLD
# Divisão: I
# Vitórias: 54
# Derrotas: 55
# Porcentagem de Vitórias: 49.54%
# ==================================================================
# Nick: **********
# ID: 207477917
# Nível: 83
# Total de Partidas: 1743
# Total de Tempo de Jogo (estimado): 1016 horas
# Campeão preferido: Lulu
# Maestria com o Campeão: 87149
# Elo: GOLD
# Divisão: IV
# Vitórias: 36
# Derrotas: 45
# Porcentagem de Vitórias: 44.44%
# ==================================================================
# Nick: **********
# ID: 211498111
# Nível: 142
# Total de Partidas: 4307
# Total de Tempo de Jogo (estimado): 2512 horas
# Campeão preferido: Lux
# Maestria com o Campeão: 223539
# Elo: PLATINUM
# Divisão: V
# Vitórias: 48
# Derrotas: 35
# Porcentagem de Vitórias: 57.83%
# ==================================================================
# Nick: **********
# ID: 201497079
# Nível: 38
# Total de Partidas: 3152
# Total de Tempo de Jogo (estimado): 1838 horas
# Campeão preferido: Thresh
# Maestria com o Campeão: 184854
# Elo: GOLD
# Divisão: III
# Vitórias: 7
# Derrotas: 3
# Porcentagem de Vitórias: 70.0%
# ==================================================================
# Nick: **********
# ID: 202581137
# Nível: 87
# Total de Partidas: 2554
# Total de Tempo de Jogo (estimado): 1489 horas
# Campeão preferido: Thresh
# Maestria com o Campeão: 419324
# Elo: GOLD
# Divisão: IV
# Vitórias: 103
# Derrotas: 84
# Porcentagem de Vitórias: 55.08%
# ==================================================================
# Nick: **********
# ID: 214430474
# Nível: 47
# Total de Partidas: 408
# Total de Tempo de Jogo (estimado): 238 horas
# Campeão preferido: Tryndamere
# Maestria com o Campeão: 16936
# Elo: SILVER
# Divisão: IV
# Vitórias: 20
# Derrotas: 30
# Porcentagem de Vitórias: 40.0%
# ==================================================================
# Nick: **********
# ID: 211196129
# Nível: 123
# Total de Partidas: 3141
# Total de Tempo de Jogo (estimado): 1832 horas
# Campeão preferido: Ryze
# Maestria com o Campeão: 100737
# Elo: GOLD
# Divisão: V
# Vitórias: 191
# Derrotas: 180
# Porcentagem de Vitórias: 51.48%
# ==================================================================
# Nick: **********
# ID: 201726538
# Nível: 89
# Total de Partidas: 1078
# Total de Tempo de Jogo (estimado): 628 horas
# Campeão preferido: Lux
# Maestria com o Campeão: 118924
# Elo: SILVER
# Divisão: I
# Vitórias: 125
# Derrotas: 137
# Porcentagem de Vitórias: 47.71%
# ==================================================================
# Nick: **********
# ID: 204211392
# Nível: 103
# Total de Partidas: 2651
# Total de Tempo de Jogo (estimado): 1546 horas
# Campeão preferido: Yasuo
# Maestria com o Campeão: 86505
# Elo: PLATINUM
# Divisão: V
# Vitórias: 131
# Derrotas: 136
# Porcentagem de Vitórias: 49.06%
# ==================================================================
# Nick: **********
# ID: 209546058
# Nível: 110
# Total de Partidas: 4219
# Total de Tempo de Jogo (estimado): 2461 horas
# Campeão preferido: Thresh
# Maestria com o Campeão: 216549
# Elo: PLATINUM
# Divisão: V
# Vitórias: 79
# Derrotas: 77
# Porcentagem de Vitórias: 50.64%
# ==================================================================
# Nick: **********
# ID: 212605830
# Nível: 77
# Total de Partidas: 2414
# Total de Tempo de Jogo (estimado): 1408 horas
# Campeão preferido: Jinx
# Maestria com o Campeão: 123404
# Elo: SILVER
# Divisão: IV
# Vitórias: 4
# Derrotas: 7
# Porcentagem de Vitórias: 36.36%
# ==================================================================

# %%
niveis = []
partidas = []
horas = []
campeoes = []
maestrias = []
elos = []
ranks = []
vitorias = []
derrotas = []
winrates = []

for jogador in players:
    if jogador != None:
        niveis.append(jogador.Summoner.summonerLevel)
        partidas.append(jogador.MatchList.totalGames)
        horas.append(jogador.MatchList.totalHours)
        campeoes.append(jogador.Champions.mainChampionName)
        maestrias.append(jogador.Champions.mainChampionPoints)
        elos.append(jogador.Leagues.tier)
        ranks.append(jogador.Leagues.rank)
        vitorias.append(jogador.Leagues.wins)
        derrotas.append(jogador.Leagues.losses)
        winrates.append(jogador.Leagues.winrate)
    else:
        niveis.append("")
        partidas.append("")
        horas.append("")
        campeoes.append("")
        maestrias.append("")
        elos.append("")
        ranks.append("")
        vitorias.append("")
        derrotas.append("")
        winrates.append("")

# %%
df['Nivel'] = niveis
df['Num_Partidas'] = partidas
df['Horas_Jogadas'] = horas
df['Campeao_Preferido'] = campeoes
df['Maestria'] = maestrias
df['Elo'] = elos
df['Divisao'] = ranks
df['Vitorias'] = vitorias
df['Derrotas'] = derrotas
df['Porcentagem_Vitorias'] = winrates

# %%
df.to_csv('dadosExtraidos.csv', sep=',')
