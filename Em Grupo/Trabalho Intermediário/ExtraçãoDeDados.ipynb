# %%
import pandas as pd
import numpy as np

# %run Biblioteca.ipynb

# %%
df = pd.read_csv('dados.csv')

# %%
df['Ano_Ingresso'] = pd.to_numeric(df['Ano_Ingresso'])
df['CR'] = pd.to_numeric(df['CR'])
df['Joga_Algo'] = df['Joga_Algo']==1
df['Joga_LoL'] = df['Joga_LoL']==1

# %%
players = []
semNicks = df['Nick'].isnull()
n = 0
for linha in df.itertuples():
    if semNicks[n] != True:
        players.append(Player(linha.Nick))
    else:
        players.append(None)
    n = n+1

# %%
for jogador in players:
    if jogador != None:
        print("Nick: **********")
        print("ID: " + jogador.Summoner.accountId)
        print("Nível: " + jogador.Summoner.summonerLevel)
        print("Total de Partidas: " +  jogador.MatchList.totalGames)
        print("Total de Tempo de Jogo (estimado): " +  jogador.MatchList.totalHours + " horas")
        print("Campeão preferido: " + jogador.Champions.mainChampionName)
        print("Maestria com o Campeão: " + jogador.Champions.mainChampionPoints)
        print("Elo: "+ jogador.Leagues.tier)
        print("Divisão: " + jogador.Leagues.rank)
        print("Vitórias: " + str(jogador.Leagues.wins))
        print("Derrotas: " + str(jogador.Leagues.losses))
        print("Porcentagem de Vitórias: " + str(jogador.Leagues.winrate) + "%")
        print("==================================================================")
# Out:
# Nick: **********
# ID: 200304136
# Nível: 89
# Total de Partidas: 3767
# Total de Tempo de Jogo (estimado): 2197 horas
# Campeão preferido: Yasuo
# Maestria com o Campeão: 124061
# Elo: GOLD
# Divisão: I
# Vitórias: 11
# Derrotas: 22
# Porcentagem de Vitórias: 33.33%
# ==================================================================
# Nick: **********
# ID: 213331961
# Nível: 164
# Total de Partidas: 4778
# Total de Tempo de Jogo (estimado): 2787 horas
# Campeão preferido: Braum
# Maestria com o Campeão: 136457
# Elo: PLATINUM
# Divisão: III
# Vitórias: 142
# Derrotas: 122
# Porcentagem de Vitórias: 53.79%
# ==================================================================
# Nick: **********
# ID: 205747689
# Nível: 86
# Total de Partidas: 1729
# Total de Tempo de Jogo (estimado): 1008 horas
# Campeão preferido: Miss Fortune
# Maestria com o Campeão: 24000
# Elo:
# Divisão:
# Vitórias:
# Derrotas:
# Porcentagem de Vitórias: %
# ==================================================================
# Nick: **********
# ID: 201458849
# Nível: 114
# Total de Partidas: 3704
# Total de Tempo de Jogo (estimado): 2160 horas
# Campeão preferido: Janna
# Maestria com o Campeão: 142484
# Elo: GOLD
# Divisão: IV
# Vitórias: 36
# Derrotas: 32
# Porcentagem de Vitórias: 52.94%
# ==================================================================
# Nick: **********
# ID: 210725644
# Nível: 113
# Total de Partidas: 3166
# Total de Tempo de Jogo (estimado): 1846 horas
# Campeão preferido: Tahm Kench
# Maestria com o Campeão: 206102
# Elo: SILVER
# Divisão: II
# Vitórias: 76
# Derrotas: 85
# Porcentagem de Vitórias: 47.2%
# ==================================================================
# Nick: **********
# ID: 215095300
# Nível: 138
# Total de Partidas: 3332
# Total de Tempo de Jogo (estimado): 1943 horas
# Campeão preferido: Zed
# Maestria com o Campeão: 218438
# Elo: PLATINUM
# Divisão: V
# Vitórias: 166
# Derrotas: 155
# Porcentagem de Vitórias: 51.71%
# ==================================================================
# Nick: **********
# ID: 202135935
# Nível: 104
# Total de Partidas: 2821
# Total de Tempo de Jogo (estimado): 1645 horas
# Campeão preferido: Rek'Sai
# Maestria com o Campeão: 134568
# Elo: PLATINUM
# Divisão: IV
# Vitórias: 10
# Derrotas: 0
# Porcentagem de Vitórias: 100.0%
# ==================================================================
# Nick: **********
# ID: 200585791
# Nível: 121
# Total de Partidas: 4091
# Total de Tempo de Jogo (estimado): 2386 horas
# Campeão preferido: Poppy
# Maestria com o Campeão: 200136
# Elo: DIAMOND
# Divisão: V
# Vitórias: 27
# Derrotas: 11
# Porcentagem de Vitórias: 71.05%
# ==================================================================
# Nick: **********
# ID: 214947813
# Nível: 80
# Total de Partidas: 1584
# Total de Tempo de Jogo (estimado): 924 horas
# Campeão preferido: Miss Fortune
# Maestria com o Campeão: 122222
# Elo: GOLD
# Divisão: IV
# Vitórias: 87
# Derrotas: 74
# Porcentagem de Vitórias: 54.04%
# ==================================================================
# Nick: **********
# ID: 204808303
# Nível: 107
# Total de Partidas: 1603
# Total de Tempo de Jogo (estimado): 935 horas
# Campeão preferido: Jax
# Maestria com o Campeão: 63944
# Elo: SILVER
# Divisão: III
# Vitórias: 11
# Derrotas: 13
# Porcentagem de Vitórias: 45.83%
# ==================================================================
# Nick: **********
# ID: 217440093
# Nível: 113
# Total de Partidas: 1328
# Total de Tempo de Jogo (estimado): 774 horas
# Campeão preferido: Zoe
# Maestria com o Campeão: 109381
# Elo: SILVER
# Divisão: IV
# Vitórias: 32
# Derrotas: 42
# Porcentagem de Vitórias: 43.24%
# ==================================================================
# Nick: **********
# ID: 204265094
# Nível: 79
# Total de Partidas: 1149
# Total de Tempo de Jogo (estimado): 670 horas
# Campeão preferido: Alistar
# Maestria com o Campeão: 90727
# Elo: GOLD
# Divisão: V
# Vitórias: 76
# Derrotas: 67
# Porcentagem de Vitórias: 53.15%
# ==================================================================
# Nick: **********
# ID: 1712879
# Nível: 74
# Total de Partidas: 2263
# Total de Tempo de Jogo (estimado): 1320 horas
# Campeão preferido: Lee Sin
# Maestria com o Campeão: 174866
# Elo: GOLD
# Divisão: I
# Vitórias: 54
# Derrotas: 54
# Porcentagem de Vitórias: 50.0%
# ==================================================================
# Nick: **********
# ID: 207477917
# Nível: 82
# Total de Partidas: 1728
# Total de Tempo de Jogo (estimado): 1008 horas
# Campeão preferido: Lulu
# Maestria com o Campeão: 86998
# Elo: GOLD
# Divisão: IV
# Vitórias: 36
# Derrotas: 45
# Porcentagem de Vitórias: 44.44%
# ==================================================================
# Nick: **********
# ID: 211498111
# Nível: 141
# Total de Partidas: 4321
# Total de Tempo de Jogo (estimado): 2520 horas
# Campeão preferido: Lux
# Maestria com o Campeão: 221069
# Elo: PLATINUM
# Divisão: V
# Vitórias: 48
# Derrotas: 35
# Porcentagem de Vitórias: 57.83%
# ==================================================================
# Nick: **********
# ID: 201497079
# Nível: 38
# Total de Partidas: 3199
# Total de Tempo de Jogo (estimado): 1866 horas
# Campeão preferido: Thresh
# Maestria com o Campeão: 184854
# Elo: GOLD
# Divisão: III
# Vitórias: 7
# Derrotas: 3
# Porcentagem de Vitórias: 70.0%
# ==================================================================
# Nick: **********
# ID: 202581137
# Nível: 86
# Total de Partidas: 2551
# Total de Tempo de Jogo (estimado): 1488 horas
# Campeão preferido: Thresh
# Maestria com o Campeão: 409423
# Elo: GOLD
# Divisão: V
# Vitórias: 99
# Derrotas: 82
# Porcentagem de Vitórias: 54.7%
# ==================================================================
# Nick: **********
# ID: 214430474
# Nível: 46
# Total de Partidas: 404
# Total de Tempo de Jogo (estimado): 235 horas
# Campeão preferido: Tryndamere
# Maestria com o Campeão: 16936
# Elo: SILVER
# Divisão: IV
# Vitórias: 20
# Derrotas: 30
# Porcentagem de Vitórias: 40.0%
# ==================================================================
# Nick: **********
# ID: 211196129
# Nível: 122
# Total de Partidas: 3109
# Total de Tempo de Jogo (estimado): 1813 horas
# Campeão preferido: Ryze
# Maestria com o Campeão: 100737
# Elo: GOLD
# Divisão: V
# Vitórias: 191
# Derrotas: 180
# Porcentagem de Vitórias: 51.48%
# ==================================================================
# Nick: **********
# ID: 201726538
# Nível: 87
# Total de Partidas: 1061
# Total de Tempo de Jogo (estimado): 618 horas
# Campeão preferido: Lux
# Maestria com o Campeão: 118924
# Elo: SILVER
# Divisão: I
# Vitórias: 121
# Derrotas: 132
# Porcentagem de Vitórias: 47.83%
# ==================================================================
# Nick: **********
# ID: 204211392
# Nível: 102
# Total de Partidas: 2653
# Total de Tempo de Jogo (estimado): 1547 horas
# Campeão preferido: Yasuo
# Maestria com o Campeão: 86505
# Elo: PLATINUM
# Divisão: V
# Vitórias: 131
# Derrotas: 133
# Porcentagem de Vitórias: 49.62%
# ==================================================================
# Nick: **********
# ID: 209546058
# Nível: 109
# Total de Partidas: 4250
# Total de Tempo de Jogo (estimado): 2479 horas
# Campeão preferido: Thresh
# Maestria com o Campeão: 216549
# Elo: PLATINUM
# Divisão: V
# Vitórias: 79
# Derrotas: 77
# Porcentagem de Vitórias: 50.64%
# ==================================================================
# Nick: **********
# ID: 212605830
# Nível: 77
# Total de Partidas: 2413
# Total de Tempo de Jogo (estimado): 1407 horas
# Campeão preferido: Jinx
# Maestria com o Campeão: 123404
# Elo: SILVER
# Divisão: IV
# Vitórias: 4
# Derrotas: 7
# Porcentagem de Vitórias: 36.36%
# ==================================================================

# %%
niveis = []
partidas = []
horas = []
campeoes = []
maestrias = []
elos = []
ranks = []
vitorias = []
derrotas = []
winrates = []

for jogador in players:
    if jogador != None:
        niveis.append(jogador.Summoner.summonerLevel)
        partidas.append(jogador.MatchList.totalGames)
        horas.append(jogador.MatchList.totalHours)
        campeoes.append(jogador.Champions.mainChampionName)
        maestrias.append(jogador.Champions.mainChampionPoints)
        elos.append(jogador.Leagues.tier)
        ranks.append(jogador.Leagues.rank)
        vitorias.append(jogador.Leagues.wins)
        derrotas.append(jogador.Leagues.losses)
        winrates.append(jogador.Leagues.winrate)
    else:
        niveis.append("")
        partidas.append("")
        horas.append("")
        campeoes.append("")
        maestrias.append("")
        elos.append("")
        ranks.append("")
        vitorias.append("")
        derrotas.append("")
        winrates.append("")

# %%
df['Nivel'] = niveis
df['Num_Partidas'] = partidas
df['Horas_Jogadas'] = horas
df['Campeao_Preferido'] = campeoes
df['Maestria'] = maestrias
df['Elo'] = elos
df['Divisao'] = ranks
df['Vitorias'] = vitorias
df['Derrotas'] = derrotas
df['Porcentagem_Vitorias'] = winrates

# %%
df.to_csv('dadosExtraidos.csv', sep=',')
