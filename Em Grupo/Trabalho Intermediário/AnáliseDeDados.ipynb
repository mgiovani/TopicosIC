# %%
import pandas as pd
import numpy as np

# %run Biblioteca.ipynb

# %%
df = pd.read_csv('dados.csv')

# %%
df['Ano de Ingresso'] = pandas.to_numeric(df['Ano de Ingresso'])
df['CR'] = pandas.to_numeric(df['CR'])
df['Joga Algo'] = df['Joga Algo']==1
df['Joga LoL'] = df['Joga LoL']==1
df.head(5)
# Out:
#    Ano de Ingresso  Joga Algo  Joga LoL Nick    CR
# 0             2015       True     False  NaN  60.6
# 1             2015       True     False  NaN  53.0
# 2             2017       True     False  NaN  43.8
# 3             2014       True     False  NaN  42.0
# 4             2014       True     False  NaN  68.4

# %%
players = []
semNicks = df['Nick'].isnull()
n = 0
for linha in df.itertuples():
    if semNicks[n] != True:
        print(linha.Nick)
        players.append(Player(linha.Nick))
    n = n+1
# Out:
# evh
# sudo rm name
# samdrix
# fesder
# 00strouker00
# fire of balerion
# zodiac spear
# thedarkdescent
# the t0m
# radswalker
# eike1v9
# BlakAiron
# CalangoG Brabo
# Lesslie
# Depressive Lux
# Malodex

# %%
for jogador in players:
    print("Nick: " + jogador.Summoner.nick)
    print("ID: " + jogador.Summoner.accountId)
    print("Nível: " + jogador.Summoner.summonerLevel)
    print("Total de Partidas: " +  jogador.MatchList.totalGames)
    print("Total de Tempo de Jogo (estimado): " +  jogador.MatchList.totalHours + " horas")
    print("Campeão preferido: " + jogador.Champions.mainChampionName)
    print("Maestria com o Campeão: " + jogador.Champions.mainChampionPoints)
    print("Elo: "+ jogador.Leagues.tier)
    print("Divisão: " + jogador.Leagues.rank)
    print("Vitórias: " + str(jogador.Leagues.wins))
    print("Derrotas: " + str(jogador.Leagues.losses))
    print("Porcentagem de Vitórias: " + str(jogador.Leagues.winrate) + "%")
    print("==================================================================")
# Out:
# Nick: evh
# ID: 200304136
# Nível: 87
# Total de Partidas: 3751
# Total de Tempo de Jogo (estimado): 2188 horas
# Campeão preferido: Yasuo
# Maestria com o Campeão: 124061
# Elo: GOLD
# Divisão: I
# Vitórias: 11
# Derrotas: 22
# Porcentagem de Vitórias: 33.33%
# ==================================================================
# Nick: sudo rm name
# ID: 213331961
# Nível: 162
# Total de Partidas: 4741
# Total de Tempo de Jogo (estimado): 2765 horas
# Campeão preferido: Braum
# Maestria com o Campeão: 135452
# Elo: PLATINUM
# Divisão: III
# Vitórias: 142
# Derrotas: 122
# Porcentagem de Vitórias: 53.79%
# ==================================================================
# Nick: samdrix
# ID: 205747689
# Nível: 84
# Total de Partidas: 1704
# Total de Tempo de Jogo (estimado): 994 horas
# Campeão preferido: Miss Fortune
# Maestria com o Campeão: 24000
# Elo:
# Divisão:
# Vitórias:
# Derrotas:
# Porcentagem de Vitórias: %
# ==================================================================
# Nick: fesder
# ID: 201458849
# Nível: 113
# Total de Partidas: 3719
# Total de Tempo de Jogo (estimado): 2169 horas
# Campeão preferido: Janna
# Maestria com o Campeão: 142484
# Elo: GOLD
# Divisão: IV
# Vitórias: 36
# Derrotas: 32
# Porcentagem de Vitórias: 52.94%
# ==================================================================
# Nick: 00strouker00
# ID: 210725644
# Nível: 110
# Total de Partidas: 3143
# Total de Tempo de Jogo (estimado): 1833 horas
# Campeão preferido: Tahm Kench
# Maestria com o Campeão: 206102
# Elo: SILVER
# Divisão: II
# Vitórias: 76
# Derrotas: 85
# Porcentagem de Vitórias: 47.2%
# ==================================================================
# Nick: fire of balerion
# ID: 215095300
# Nível: 133
# Total de Partidas: 3267
# Total de Tempo de Jogo (estimado): 1905 horas
# Campeão preferido: Zed
# Maestria com o Campeão: 218438
# Elo: PLATINUM
# Divisão: V
# Vitórias: 166
# Derrotas: 155
# Porcentagem de Vitórias: 51.71%
# ==================================================================
# Nick: zodiac spear
# ID: 202135935
# Nível: 103
# Total de Partidas: 2810
# Total de Tempo de Jogo (estimado): 1639 horas
# Campeão preferido: Rek'Sai
# Maestria com o Campeão: 134568
# Elo: PLATINUM
# Divisão: IV
# Vitórias: 10
# Derrotas: 0
# Porcentagem de Vitórias: 100.0%
# ==================================================================
# Nick: thedarkdescent
# ID: 200585791
# Nível: 119
# Total de Partidas: 4057
# Total de Tempo de Jogo (estimado): 2366 horas
# Campeão preferido: Poppy
# Maestria com o Campeão: 200136
# Elo: DIAMOND
# Divisão: V
# Vitórias: 27
# Derrotas: 11
# Porcentagem de Vitórias: 71.05%
# ==================================================================
# Nick: the t0m
# ID: 214947813
# Nível: 80
# Total de Partidas: 1578
# Total de Tempo de Jogo (estimado): 920 horas
# Campeão preferido: Miss Fortune
# Maestria com o Campeão: 122222
# Elo: GOLD
# Divisão: IV
# Vitórias: 87
# Derrotas: 74
# Porcentagem de Vitórias: 54.04%
# ==================================================================
# Nick: radswalker
# ID: 204808303
# Nível: 106
# Total de Partidas: 1594
# Total de Tempo de Jogo (estimado): 929 horas
# Campeão preferido: Jax
# Maestria com o Campeão: 63322
# Elo: SILVER
# Divisão: III
# Vitórias: 11
# Derrotas: 13
# Porcentagem de Vitórias: 45.83%
# ==================================================================
# Nick: eike1v9
# ID: 217440093
# Nível: 111
# Total de Partidas: 1304
# Total de Tempo de Jogo (estimado): 760 horas
# Campeão preferido: Zoe
# Maestria com o Campeão: 109174
# Elo: SILVER
# Divisão: IV
# Vitórias: 32
# Derrotas: 42
# Porcentagem de Vitórias: 43.24%
# ==================================================================
# Nick: BlakAiron
# ID: 204265094
# Nível: 75
# Total de Partidas: 1150
# Total de Tempo de Jogo (estimado): 670 horas
# Campeão preferido: Alistar
# Maestria com o Campeão: 89528
# Elo: GOLD
# Divisão: V
# Vitórias: 96
# Derrotas: 85
# Porcentagem de Vitórias: 53.04%
# ==================================================================
# Nick: CalangoG Brabo
# ID: 1712879
# Nível: 73
# Total de Partidas: 2289
# Total de Tempo de Jogo (estimado): 1335 horas
# Campeão preferido: Lee Sin
# Maestria com o Campeão: 174866
# Elo: GOLD
# Divisão: I
# Vitórias: 54
# Derrotas: 54
# Porcentagem de Vitórias: 50.0%
# ==================================================================
# Nick: Lesslie
# ID: 207477917
# Nível: 81
# Total de Partidas: 1718
# Total de Tempo de Jogo (estimado): 1002 horas
# Campeão preferido: Lulu
# Maestria com o Campeão: 86998
# Elo: GOLD
# Divisão: IV
# Vitórias: 36
# Derrotas: 45
# Porcentagem de Vitórias: 44.44%
# ==================================================================
# Nick: Depressive Lux
# ID: 211498111
# Nível: 140
# Total de Partidas: 4338
# Total de Tempo de Jogo (estimado): 2530 horas
# Campeão preferido: Lux
# Maestria com o Campeão: 220158
# Elo: PLATINUM
# Divisão: V
# Vitórias: 47
# Derrotas: 35
# Porcentagem de Vitórias: 57.32%
# ==================================================================
# Nick: Malodex
# ID: 201497079
# Nível: 38
# Total de Partidas: 3224
# Total de Tempo de Jogo (estimado): 1880 horas
# Campeão preferido: Thresh
# Maestria com o Campeão: 184854
# Elo: GOLD
# Divisão: III
# Vitórias: 7
# Derrotas: 3
# Porcentagem de Vitórias: 70.0%
# ==================================================================
